# %%
import seaborn as sns # visualization
import math as m 
import pandas as pd # data processing
import numpy as np # working with arrays
import matplotlib.pyplot as plt # visualization
from termcolor import colored as cl # text customization
import itertools # advanced tools
import warnings
warnings.filterwarnings('ignore')

# %%
app_record = pd.read_csv(r"E:\courses\AI All\Amit Machin Learning\Data\archive\application_record.csv")
print("Dataset size")
print(cl("Rows {} Columns {}".format(app_record.shape[0], app_record.shape[1]), attrs = ['bold'], color = 'black'))
app_record.head()
# Out:
# Dataset size
# Rows 438557 Columns 18
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
credit_record = pd.read_csv(r"E:\courses\AI All\Amit Machin Learning\Data\archive\credit_record.csv")
print("Dataset size")
print(cl("Rows {} Columns {}".format(credit_record.shape[0], credit_record.shape[1]), attrs = ['bold'], color = 'black'))
credit_record.head()
# Out:
# Dataset size
# Rows 1048575 Columns 3
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0      X
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0      C

# %%
app_record
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
df = app_record.merge(credit_record, how='inner', on=['ID'])
df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008804           M            Y               Y             0
# 2  5008804           M            Y               Y             0
# 3  5008804           M            Y               Y             0
# 4  5008804           M            Y               Y             0
#
#    AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0          427500.0          Working    Higher education     Civil marriage
# 1          427500.0          Working    Higher education     Civil marriage
# 2          427500.0          Working    Higher education     Civil marriage
# 3          427500.0          Working    Higher education     Civil marriage
# 4          427500.0          Working    Higher education     Civil marriage
#
#   NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  \
# ...

# %%
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
print(len(credit_record))
print(len(df))
# Out:
# 1048575
# 777715

# %%
df.duplicated().sum()
# Out:
# 0

# %%
pd.DataFrame(df.isna().sum()).rename(columns = {0:'See Null Values'})
# Out:
#                      See Null Values
# ID                                 0
# CODE_GENDER                        0
# FLAG_OWN_CAR                       0
# FLAG_OWN_REALTY                    0
# CNT_CHILDREN                       0
# AMT_INCOME_TOTAL                   0
# NAME_INCOME_TYPE                   0
# NAME_EDUCATION_TYPE                0
# NAME_FAMILY_STATUS                 0
# NAME_HOUSING_TYPE                  0
# DAYS_BIRTH                         0
# DAYS_EMPLOYED                      0
# FLAG_MOBIL                         0
# FLAG_WORK_PHONE                    0
# FLAG_PHONE                         0
# FLAG_EMAIL                         0
# OCCUPATION_TYPE               240048
# CNT_FAM_MEMBERS                    0
# MONTHS_BALANCE                     0
# STATUS                             0

# %%
df['OCCUPATION_TYPE'].value_counts()
# Out:
# Laborers                 131572
# Core staff                77112
# Sales staff               70362
# Managers                  67738
# Drivers                   47678
# High skill tech staff     31768
# Accountants               27223
# Medicine staff            26691
# Cooking staff             13416
# Security staff            12400
# Cleaning staff            11399
# Private service staff      6714
# Low-skill Laborers         3623
# Secretaries                3149
# Waiters/barmen staff       2557
# HR staff                   1686
# IT staff                   1319
# Realty agents              1260
# Name: OCCUPATION_TYPE, dtype: int64

# %%
df['OCCUPATION_TYPE'].fillna('others',inplace=True)

# %%
pd.DataFrame(df.isna().sum()).rename(columns = {0:'See Null Values'})
# Out:
#                      See Null Values
# ID                                 0
# CODE_GENDER                        0
# FLAG_OWN_CAR                       0
# FLAG_OWN_REALTY                    0
# CNT_CHILDREN                       0
# AMT_INCOME_TOTAL                   0
# NAME_INCOME_TYPE                   0
# NAME_EDUCATION_TYPE                0
# NAME_FAMILY_STATUS                 0
# NAME_HOUSING_TYPE                  0
# DAYS_BIRTH                         0
# DAYS_EMPLOYED                      0
# FLAG_MOBIL                         0
# FLAG_WORK_PHONE                    0
# FLAG_PHONE                         0
# FLAG_EMAIL                         0
# OCCUPATION_TYPE                    0
# CNT_FAM_MEMBERS                    0
# MONTHS_BALANCE                     0
# STATUS                             0

# %%
df['STATUS'].dtype
# Out:
# dtype('O')

# %%
df['STATUS'].replace({'C': 6, 'X' : 7}, inplace=True)
df['STATUS'] = df['STATUS'].astype(int)

# %%
df['STATUS'].dtype
# Out:
# dtype('int32')

# %%
def get_label_for_data(status):
    if status in (2,3,4,5):
        return 1  
    else:
        return 0
df['TARGET'] = df['STATUS'].apply(get_label_for_data)

# %%
df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008804           M            Y               Y             0
# 2  5008804           M            Y               Y             0
# 3  5008804           M            Y               Y             0
# 4  5008804           M            Y               Y             0
#
#    AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0          427500.0          Working    Higher education     Civil marriage
# 1          427500.0          Working    Higher education     Civil marriage
# 2          427500.0          Working    Higher education     Civil marriage
# 3          427500.0          Working    Higher education     Civil marriage
# 4          427500.0          Working    Higher education     Civil marriage
#
#   NAME_HOUSING_TYPE  ...  DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  \
# ...

# %%
df['DAYS_EMPLOYED'].value_counts()
# Out:
#  365243    127972
# -1751        1601
# -1539        1545
# -401         1498
# -2531        1319
#             ...
# -3294           1
# -3891           1
# -7049           1
# -7765           1
# -2848           1
# Name: DAYS_EMPLOYED, Length: 3640, dtype: int64

# %%
df['TARGET'].value_counts() * 100 / len(df)
# Out:
# 0    99.636371
# 1     0.363629
# Name: TARGET, dtype: float64

# %%
df = df.drop(['ID','DAYS_BIRTH','MONTHS_BALANCE','DAYS_EMPLOYED','STATUS','FLAG_MOBIL'],axis=1)

# %%
df.duplicated().sum()
# Out:
# 768943

# %%
index = []
values = []
members = []
housing = []
for indx,value in enumerate(df.AMT_INCOME_TOTAL):
    if (value in values) & (df.loc[indx]['OCCUPATION_TYPE'] in members) & (df.loc[indx]['NAME_HOUSING_TYPE'] in housing):
        index.append(indx)
    else:
        values.append(value)
        members.append(df.loc[indx]['OCCUPATION_TYPE'])
        housing.append(df.loc[indx]['NAME_HOUSING_TYPE'] in housing)
len(index)

# %%
df.loc[0]['NAME_HOUSING_TYPE']
# Out:
# 'Rented apartment'

# %%
df
# Out:
#        CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0                M            Y               Y             0
# 1                M            Y               Y             0
# 2                M            Y               Y             0
# 3                M            Y               Y             0
# 4                M            Y               Y             0
# ...            ...          ...             ...           ...
# 777710           M            N               Y             0
# 777711           M            N               Y             0
# 777712           M            N               Y             0
# 777713           M            N               Y             0
# 777714           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0          Working               Higher education
# ...

# %%
777715-777440
# Out:
# 275

# %%
df.head()
# Out:
#   CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0           M            Y               Y             0          427500.0
# 1           M            Y               Y             0          427500.0
# 2           M            Y               Y             0          427500.0
# 3           M            Y               Y             0          427500.0
# 4           M            Y               Y             0          427500.0
#
#   NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS NAME_HOUSING_TYPE  \
# 0          Working    Higher education     Civil marriage  Rented apartment
# 1          Working    Higher education     Civil marriage  Rented apartment
# 2          Working    Higher education     Civil marriage  Rented apartment
# 3          Working    Higher education     Civil marriage  Rented apartment
# 4          Working    Higher education     Civil marriage  Rented apartment
#
# ...

# %%
df['CODE_GENDER'].value_counts()
# Out:
# F    518851
# M    258864
# Name: CODE_GENDER, dtype: int64

# %%
df['FLAG_OWN_CAR'].value_counts()
# Out:
# N    473355
# Y    304360
# Name: FLAG_OWN_CAR, dtype: int64

# %%
df['FLAG_OWN_REALTY'].value_counts()
# Out:
# Y    512948
# N    264767
# Name: FLAG_OWN_REALTY, dtype: int64

# %%
df['NAME_INCOME_TYPE'].value_counts()
# Out:
# Working                 400164
# Commercial associate    183385
# Pensioner               128392
# State servant            65437
# Student                    337
# Name: NAME_INCOME_TYPE, dtype: int64

# %%
df['NAME_EDUCATION_TYPE'].value_counts()
# Out:
# Secondary / secondary special    524261
# Higher education                 213633
# Incomplete higher                 30329
# Lower secondary                    8655
# Academic degree                     837
# Name: NAME_EDUCATION_TYPE, dtype: int64

# %%
df['NAME_FAMILY_STATUS'].value_counts()
# Out:
# Married                 546619
# Single / not married     94335
# Civil marriage           60342
# Separated                45255
# Widow                    31164
# Name: NAME_FAMILY_STATUS, dtype: int64

# %%
df['NAME_HOUSING_TYPE'].value_counts()
# Out:
# House / apartment      697151
# With parents            35735
# Municipal apartment     24640
# Rented apartment        10898
# Office apartment         5636
# Co-op apartment          3655
# Name: NAME_HOUSING_TYPE, dtype: int64

# %%
df['OCCUPATION_TYPE'].value_counts()
# Out:
# others                   240048
# Laborers                 131572
# Core staff                77112
# Sales staff               70362
# Managers                  67738
# Drivers                   47678
# High skill tech staff     31768
# Accountants               27223
# Medicine staff            26691
# Cooking staff             13416
# Security staff            12400
# Cleaning staff            11399
# Private service staff      6714
# Low-skill Laborers         3623
# Secretaries                3149
# Waiters/barmen staff       2557
# HR staff                   1686
# IT staff                   1319
# Realty agents              1260
# Name: OCCUPATION_TYPE, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
column_data = ["CODE_GENDER", "FLAG_OWN_CAR", "FLAG_OWN_REALTY", "NAME_INCOME_TYPE", "NAME_EDUCATION_TYPE", "NAME_FAMILY_STATUS", "NAME_HOUSING_TYPE"]
for col in column_data:
    df[col] = le.fit_transform(df[[col]])

# %%
df = pd.get_dummies(df, drop_first=True, columns=['OCCUPATION_TYPE'])
df.head()
# Out:
#    CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0            1             1                1             0          427500.0
# 1            1             1                1             0          427500.0
# 2            1             1                1             0          427500.0
# 3            1             1                1             0          427500.0
# 4            1             1                1             0          427500.0
#
#    NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  NAME_FAMILY_STATUS  \
# 0                 4                    1                   0
# 1                 4                    1                   0
# 2                 4                    1                   0
# 3                 4                    1                   0
# 4                 4                    1                   0
#
#    NAME_HOUSING_TYPE  FLAG_WORK_PHONE  ...  \
# 0                  4                1  ...
# ...

# %%
x = df.drop(['TARGET'], axis = 1)
y = df['TARGET']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x = scaler.fit_transform(x)
x
# Out:
# array([[ 1.41574651,  1.24709546,  0.71844786, ..., -0.12728896,
#         -0.05743416,  1.49660656],
#        [ 1.41574651,  1.24709546,  0.71844786, ..., -0.12728896,
#         -0.05743416,  1.49660656],
#        [ 1.41574651,  1.24709546,  0.71844786, ..., -0.12728896,
#         -0.05743416,  1.49660656],
#        ...,
#        [ 1.41574651, -0.80186324,  0.71844786, ..., -0.12728896,
#         -0.05743416, -0.66817828],
#        [ 1.41574651, -0.80186324,  0.71844786, ..., -0.12728896,
#         -0.05743416, -0.66817828],
#        [ 1.41574651, -0.80186324,  0.71844786, ..., -0.12728896,
#         -0.05743416, -0.66817828]])

# %%
from sklearn.decomposition import PCA
pca=PCA(27)
x = pca.fit_transform(x)

# %%
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

undersample = RandomUnderSampler(random_state=0)

x, y = undersample.fit_resample(x, y)

counter = Counter(y)

print(counter)

for k,v in counter.items():
    per = v / len(y) * 100
    print('Class=%d, n=%d (%.2f%%)' % (k, v, per))


plt.bar(counter.keys(), counter.values())
plt.show()
# Out:
# Counter({0: 2828, 1: 2828})
# Class=0, n=2828 (50.00%)
# Class=1, n=2828 (50.00%)

# %%
from sklearn.model_selection import train_test_split
x_train ,x_test ,y_train,y_test = train_test_split(x, y, test_size = 0.3, random_state=42, shuffle=True)

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression(fit_intercept=True, max_iter=100000)
log_model.fit(x_train,y_train)
y_pred = log_model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[543 336]
#  [339 479]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62       879
#            1       0.59      0.59      0.59       818
#
#     accuracy                           0.60      1697
#    macro avg       0.60      0.60      0.60      1697
# weighted avg       0.60      0.60      0.60      1697

# %%
accuracy_score(y_train,tr_y_pred) *100
# Out:
# 96.86789593331649

# %%
accuracy_score(y_test,ts_y_pred) *100
# Out:
# 92.57513258691809

# %%
model = GradientBoostingClassifier()
model.fit(x_train,y_train)
tr_y_pred = model.predict(x_train)
ts_y_pred = model.predict(x_test)

# %%
accuracy_score(y_train,tr_y_pred) *100
# Out:
# 86.46122758272291

# %%
accuracy_score(y_test,ts_y_pred) *100
# Out:
# 83.32351208014143

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
rf = RandomForestClassifier()

rf_params = {
    'n_estimators': [100, 200, 300, 500],
    'max_depth': [3, 5, 7, 9],
    'min_samples_split': [2, 3, 4, 5],
    'min_samples_leaf': [1, 2, 3, 5],
    'random_state': [42]
}

rf_search = GridSearchCV(rf, param_grid=rf_params, cv=5, scoring='accuracy', n_jobs=-1)
rf_search.fit(x_train, y_train)
best_mse = rf_search.best_score_
best_rmse = best_mse

print('Best score: {}, Best params: {}'.format(round(best_rmse, 4), rf_search.best_estimator_))
# Out:
# Best score: 0.8818, Best params: RandomForestClassifier(max_depth=9, n_estimators=200, random_state=42)

# %%
model = RandomForestClassifier(max_depth=9, n_estimators=200, random_state=42)
model.fit(x_train,y_train)
tr_y_pred = model.predict(x_train)
ts_y_pred = model.predict(x_test)

# %%
accuracy_score(y_train,tr_y_pred) *100
# Out:
# 93.20535488759788

# %%
accuracy_score(y_test,ts_y_pred) *100
# Out:
# 89.51090159104301

# %%
from lightgbm import LGBMClassifier
lgbm = LGBMClassifier(random_state=42)
lgbm_params = {
    'num_leaves': [25, 31, 35],
    'learning_rate': [0.01, 0.05, 0.1, 0.5],
    'n_estimators': [100, 300, 500, 1000],
    'max_depth': [3, 7, 11],
    'random_state': [42]
}

lgbm_search = GridSearchCV(lgbm, param_grid=lgbm_params, cv=5, scoring='accuracy', n_jobs=-1)
lgbm_search.fit(x_train, y_train)
best_mse = lgbm_search.best_score_
best_rmse = best_mse

print('Best score: {}, Best params: {}'.format(best_rmse, lgbm_search.best_estimator_))
# Out:
# Best score: 0.9078037007240546, Best params: LGBMClassifier(learning_rate=0.05, max_depth=11, n_estimators=1000,
#                num_leaves=35, random_state=42)

# %%
model = LGBMClassifier(learning_rate=0.05, max_depth=11, n_estimators=1000,num_leaves=35, random_state=42)
model.fit(x_train,y_train)
tr_y_pred = model.predict(x_train)
ts_y_pred = model.predict(x_test)

# %%
accuracy_score(y_train,tr_y_pred) *100
# Out:
# 96.86789593331649

# %%
accuracy_score(y_test,ts_y_pred) *100
# Out:
# 92.75191514437242

# %%
from sklearn.metrics import confusion_matrix,classification_report


print(confusion_matrix(y_test,ts_y_pred))
print(classification_report(y_test,ts_y_pred))
# Out:
# [[819  60]
#  [ 63 755]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       879
#            1       0.93      0.92      0.92       818
#
#     accuracy                           0.93      1697
#    macro avg       0.93      0.93      0.93      1697
# weighted avg       0.93      0.93      0.93      1697
